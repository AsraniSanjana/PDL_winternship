# %% [markdown]
# <a href="https://colab.research.google.com/github/AsraniSanjana/PDL_winternship/blob/main/ColabFiles/task2_everywhere_ml%26m2cgen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Reference**: https://eloquentarduino.com/arduino-machine-learning/

# %%
pip install everywhereml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.7 MB/s eta 0:00:00
# ...
#   Created wheel for everywhereml: filename=everywhereml-0.2.24-py3-none-any.whl size=79318 sha256=5d4e50e24b722e8c3f8afe99179ddf4277b94ea9c815a7240d73b8e211e25567
#   Stored in directory: /root/.cache/pip/wheels/3b/99/c2/328ae739557c5935cdc66dda94b3c6949026acf44f11b68c06
# ...
#   Created wheel for hexdump: filename=hexdump-3.3-py3-none-any.whl size=8894 sha256=594a0c297fdd18cf633cb0d2a8bbfcd58b721723c9643a7c1f4afeb7c6251d9a
#   Stored in directory: /root/.cache/pip/wheels/26/28/f7/f47d7ecd9ae44c4457e72c8bb617ef18ab332ee2b2a1047e87
# ...

# %%
from sklearn.datasets import make_blobs
from everywhereml.sklearn.ensemble import RandomForestClassifier

X, y = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)
clf = RandomForestClassifier(n_estimators=10)

clf.fit(X, y)
# Out:
# RandomForestClassifier(base_estimator=deprecated, bootstrap=True, ccp_alpha=0.0, class_name=RandomForestClassifier, class_weight=None, criterion=gini, estimator=DecisionTreeClassifier(), estimator_params=('criterion', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'random_state', 'ccp_alpha'), max_depth=None, max_features=sqrt, max_leaf_nodes=None, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None, num_outputs=3, oob_score=False, package_name=everywhereml.sklearn.ensemble, random_state=None, template_folder=everywhereml/sklearn/ensemble, verbose=0, warm_start=False)

# %%
X
# Out:
# array([[ 2.63185834,  0.6893649 ],
#        [ 0.08080352,  4.69068983],
#        [ 3.00251949,  0.74265357],
#        [-0.63762777,  4.09104705],
#        [-0.07228289,  2.88376939],
#        [ 0.62835793,  4.4601363 ],
#        [-2.67437267,  2.48006222],
#        [-0.57748321,  3.0054335 ],
#        [ 2.72756228,  1.3051255 ],
#        [ 0.34194798,  3.94104616],
#        [ 1.70536064,  4.43277024],
#        [ 2.20656076,  5.50616718],
#        [ 2.52092996, -0.63858003],
#        [ 2.50904929,  5.7731461 ],
#        [-2.27165884,  2.09144372],
#        [ 3.92282648,  1.80370832],
#        [-1.62535654,  2.25440397],
#        [ 0.1631238 ,  2.57750473],
#        [-1.59514562,  4.63122498],
#        [-2.63128735,  2.97004734],
#        [-2.17052242,  0.69447911],
#        [-1.56618683,  1.74978876],
#        [-0.88677249,  1.30092622],
#        [ 0.08848433,  2.32299086],
#        [ 0.9845149 ,  1.95211539],
#        [ 2.18217961,  1.29965302],
#        [ 1.28535145,  1.43691285],
# ...

# %%
y
# Out:
# array([1, 0, 1, 0, 0, 0, 2, 2, 1, 0, 0, 0, 1, 0, 2, 1, 2, 0, 2, 2, 2, 2,
#        2, 0, 1, 1, 1, 1, 2, 2, 0, 1, 1, 0, 2, 2, 0, 1, 1, 2, 2, 1, 1, 0,
#        0, 0, 1, 1, 2, 2, 2, 1, 0, 1, 2, 2, 1, 1, 0, 1, 1, 2, 2, 2, 2, 1,
#        0, 2, 1, 0, 2, 0, 0, 1, 1, 0, 0, 0, 2, 1, 0, 0, 1, 0, 1, 0, 0, 0,
#        1, 0, 1, 1, 2, 2, 2, 2, 0, 0, 2, 2])

# %% [markdown]
# # **plotting the reln bw X & y**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from everywhereml.sklearn.ensemble import RandomForestClassifier

# Generate the dataset
X, y = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)

# Train a RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf.fit(X, y)

# Combine X and y into a DataFrame
import pandas as pd
df = pd.DataFrame(X, columns=["Feature_1", "Feature_2"])
df["Target"] = y

# Create a pairplot
sns.pairplot(df, hue="Target", markers=["o", "s", "D"], palette="viridis")
plt.show()

# %%
from sklearn.datasets import make_blobs
from everywhereml.sklearn.ensemble import RandomForestClassifier

# Generate synthetic dataset
X, y = make_blobs(n_samples=100, centers=3, n_features=2, random_state=0)

# Train a RandomForestClassifier
clf = RandomForestClassifier(n_estimators=10)
clf.fit(X, y)

# New input for prediction
new_data_point = [[1.5, 2.5]]  # Replace with your actual feature values

# Make a prediction
predicted_class = clf.predict(new_data_point)

print("Generated Data:")
print("Input features (X):", X[:5])  # Printing only the first 5 data points for brevity
print("Target variable (y):", y[:5])

print("\nNew Input for Prediction:")
print("New data point (new_data_point):", new_data_point)

print("\nPrediction:")
print("Predicted class:", predicted_class)
# Out:
# Generated Data:
# Input features (X): [[ 2.63185834  0.6893649 ]
#  [ 0.08080352  4.69068983]
#  [ 3.00251949  0.74265357]
#  [-0.63762777  4.09104705]
#  [-0.07228289  2.88376939]]
# Target variable (y): [1 0 1 0 0]
#
# New Input for Prediction:
# New data point (new_data_point): [[1.5, 2.5]]
#
# Prediction:
# Predicted class: [1]

# %%
'''
  Now we convert the classifier to C++ with a single line of code
  - instance_name will create an instance of the classifier in the produced code
    (you will use this name later)
'''
print(clf.to_arduino(instance_name='blobClassifier'))
# Out:
# #ifndef UUID135911236015808
# #define UUID135911236015808
#
# /**
#   * RandomForestClassifier(base_estimator=deprecated, bootstrap=True, ccp_alpha=0.0, class_name=RandomForestClassifier, class_weight=None, criterion=gini, estimator=DecisionTreeClassifier(), estimator_params=('criterion', 'max_depth', 'min_samples_split', 'min_samples_leaf', 'min_weight_fraction_leaf', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'random_state', 'ccp_alpha'), max_depth=None, max_features=sqrt, max_leaf_nodes=None, max_samples=None, min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None, num_outputs=3, oob_score=False, package_name=everywhereml.sklearn.ensemble, random_state=None, template_folder=everywhereml/sklearn/ensemble, verbose=0, warm_start=False)
#  */
# class RandomForestClassifier {
#     public:
#
#         /**
#          * Predict class from features
#          */
#         int predict(float *x) {
# ...

# %% [markdown]
# ---
#
#
# # copy paste this CPP op code into a sketch named: **blob_classifier.h**
#
#
# ---
#
#
#
# # and make a new sketch: **\'rf\'** :
#
# \#include "blob_classifier.h"
#
# void setup() {
#
#     Serial.begin(115200);
# }
#
# void loop() {
#
#     float input[2] = {1, 1};
#     Serial.print("Prediction: ");
#     Serial.println(blobClassifier.predict(input));
# }
#
#
# ---
#
# and now compile and upload rf, open serial monitor to check its op

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **REGRESSION MODEL ON SALARY VS EXP DATATSET**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Generate synthetic dataset
np.random.seed(42)
experience = np.random.uniform(1, 20, 100)  # 100 data points for experience
salary = 5000 + 200 * experience + np.random.normal(0, 1500, 100)  # Linear relation with some noise

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(experience.reshape(-1, 1), salary, test_size=0.2, random_state=42)

# Train a Linear Regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')

# Plot the results
plt.scatter(X_test, y_test, color='black', label='True values')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predicted values')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.title('Salary vs Experience Prediction')
plt.legend()
plt.show()
# Out:
# Mean Squared Error: 1470823.91
# R-squared: 0.30

# %%
user_experience = float(input("Enter years of experience: "))

# Predict the corresponding salary
predicted_salary = model.predict([[user_experience]])

print(f"Predicted Salary for {user_experience} years of experience: ${predicted_salary[0]:.2f}")
# Out:
# Enter years of experience: 8
# Predicted Salary for 8.0 years of experience: $6592.57

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #**code to convert the model to arduino code for .h file**

# %%
print(model.to_arduino(instance_name='LinRegModel'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-37f050a78de8> in <cell line: 1>()
# ----> 1 print(model.to_arduino(instance_name='LinRegModel'))
#
# AttributeError: 'LinearRegression' object has no attribute 'to_arduino'

# %%
print(m2c.export_to_c(model))
# Out:
# double score(double * input) {
#     return 5246.055717480443 + input[0] * 168.3142617074118;
# }

# %% [markdown]
# ---
#
#
# conclu: THUS, .TO_ARDUINO METHOD ONLY WORKS FOR FOLLOWING CLASSIFIER MODELS
# 1. DT (TREE BASED)
# 2. RF (ENSEMBLE)
# 3. XGBOOST
#
# not for regressor models.
#
#
# ---

# %% [markdown]
# # **py to c for .h**
#
# FOR REGRESSION
# ---
#
#
# **USING M2CGEN**

# %%
# !pip install m2cgen
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 2.2 MB/s eta 0:00:00
# ...

# %%
from sklearn.datasets import load_diabetes
from sklearn import linear_model
import m2cgen as m2c

X, y = load_diabetes(return_X_y=True)

estimator = linear_model.LinearRegression()
estimator.fit(X, y)

code = m2c.export_to_c(estimator)

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
code
# Out:
# 'double score(double * input) {\n    return 152.13348416289597 + input[0] * -10.009866299810684 + input[1] * -239.81564367242237 + input[2] * 519.84592005446 + input[3] * 324.38464550232356 + input[4] * -792.1756385522286 + input[5] * 476.7390210052569 + input[6] * 101.04326793803338 + input[7] * 177.06323767134643 + input[8] * 751.2736995571034 + input[9] * 67.62669218370515;\n}\n'

# %% [markdown]
# ---
#
#
# Copy paste this code in a file named: diabetesReg.h
#
#
# ---
#
#
# create a new sketch called: **\'diab\'** :
#
# \#include "diabetesReg.h"
#
# void setup() {
#
#     Serial.begin(115200);
# }
#
# void loop() {
#     // replace with your actual feature vector
#     float input[10] = {0.1, -0.2, 0.2, -0.4, 0.5,0.6, 0.7, -0.8, 0.9, -1.0 };
#
#     // print ur y for given X (input)
#     Serial.print("Prediction: ");
#     Serial.println(score(input));
# }
#
#
# ---
#
#
# and now compile and upload diab, open serial monitor to check its op

# %%
# New input for prediction
new_X = [[0.1, -0.2, 0.2, -0.4, 0.5,0.6, 0.7, -0.8, 0.9, -1.0 ]]

# Make a prediction
predicted_y = estimator.predict(new_X)

# Print the result
print("Predicted y:", predicted_y)
# Out:
# Predicted y: [600.86588024]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **\'salary.h\'** has the op c code
# ---
# **\'Salary_main\'** has the arduino code to provide ip:
#
# \#include "salary.h"
#
# void setup() {
#
#     Serial.begin(115200);
# }
#
# void loop() {
#     // replace with your actual feature vector
#     float input[] = { 8 };
#
#     Serial.print("Prediction: ");
#     Serial.println(score(input));
# }
#
# ---
